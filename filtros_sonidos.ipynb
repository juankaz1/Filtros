# %%
# %pylab inline
import scikits.audiolab as audio
from __future__ import division
import matplotlib.pyplot as plt
from scipy.fftpack import fft, fftfreq
import numpy as N

import scikits.audiolab as audio

"""filename    = 'original.wav'
a           = audio.sndfile(filename, 'read')

tmp         = a.read_frames(len(input_signal))
import pylab as P
plot(tmp)"""
input_signal, sampling_rate, enc = audio.wavread("original.wav")
time_array = arange(0,len(input_signal)/float(sampling_rate),1/float(sampling_rate))
time_array = time_array[1:]
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fft']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
p=fft(input_signal)
w =fftfreq(len(input_signal),1)
plot(w,p)

# %%
#Ruido blanco

pblanco = p/abs(p)
blanco = ifft(pblanco)
plot(blanco.real)
salida= audio.Sndfile("ruido_balnco.wav", 'w', audio.Format('wav'), 1, sampling_rate)
salida.write_frames(blanco.real)
salida.close()

# %%
#Ruido rosa

sup=w[1:].max()
pRosa=exp(-(abs(w)/sup))*(p/abs(p))  
rosa= ifft(pRosa)
plot(rosa.real)
salida= audio.Sndfile("ruido_rosa.wav"  ,'w' , audio.Format('wav'),1, sampling_rate)
salida.write_frames(rosa.real)
salida.close()
